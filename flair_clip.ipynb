# %%
# !pip install datasets transformers torch

# %% [markdown]
# # Load dataset and models

# %%
from datasets import load_dataset
from transformers import CLIPProcessor, CLIPModel
import torch

ds = load_dataset("IGNF/FLAIR_1_osm_clip")

model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to("cuda")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
# Out:
# Resolving data files:   0%|          | 0/54 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/51 [00:00<?, ?it/s]
# 2024-09-10 22:18:43.104857: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-10 22:18:43.237175: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-10 22:18:43.274197: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-10 22:18:43.482276: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-10 22:18:45.009005: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model = model.to("cuda")

# %% [markdown]
# # Compute the embeddings

# %%
def clip_embed(images=None, text=None):
    if not images and not text:
         raise ValueError("Specify eiter text or image")
    
    inputs = processor(text=text, images=images, return_tensors="pt", padding=True).to("cuda")

    with torch.no_grad():
        if not images:
            return model.get_text_features(**inputs)
        elif not text:
            return model.get_image_features(**inputs)
        else:
            return model(**inputs)
    
    return outputs

def clip_embed_batch(images):
    inputs = processor(images=images, return_tensors="pt", padding=True)
    with torch.no_grad():
        outputs = model.get_image_features(**inputs)
    return outputs[0].numpy()


def add_clip_embeddings_batch(batch):
    images = batch['image']
    embeddings = clip_embed_batch(images)
    batch['clip_embedding'] = embeddings
    return batch

# %%
from tqdm.notebook import tqdm

embeddings = {}

# this should take around 20mn for 60k images
batch_size = 10
for i in tqdm(range(0, len(ds['train']), batch_size)):
    batch = ds['train'][i:i + batch_size]['image']
    embeds = clip_embed(batch)
    for j, embed in enumerate(embeds):
        embeddings[i+j] = embed.cpu().numpy()
# Out:
#   0%|          | 0/6172 [00:00<?, ?it/s]

# %%
len(embeddings)
# Out:
# 61712

# %%
ds["train"].add_column("clip_embeddings",  [e[0] for e in embeddings])

# Now the dataset has a new column 'new_column'
print(ds)['train']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/datasets/fingerprint.py:294, in update_fingerprint(fingerprint, transform, transform_args)
#     293 try:
# --> 294     hasher.update(transform_args[key])
#     295 except:  # noqa various errors might raise here from pickle or dill
#
# File ~/.local/lib/python3.11/site-packages/datasets/fingerprint.py:232, in Hasher.update(self, value)
#     231 header_for_update = f"=={type(value)}=="
# --> 232 value_for_update = self.hash(value)
#     233 self.m.update(header_for_update.encode("utf8"))
#
# File ~/.local/lib/python3.11/site-packages/datasets/fingerprint.py:228, in Hasher.hash(cls, value)
#     226 @classmethod
#     227 def hash(cls, value: Any) -> str:
# --> 228     return cls.hash_bytes(dumps(value))
#
# File ~/.local/lib/python3.11/site-packages/datasets/utils/_dill.py:109, in dumps(obj)
#     108 file = BytesIO()
# --> 109 dump(obj, file)
#     110 return file.getvalue()
#
# File ~/.local/lib/python3.11/site-packages/datasets/utils/_dill.py:103, in dump(obj, file)
#     102 """Pickle an object to a file."""
# --> 103 Pickler(file, recurse=True).dump(obj)
#
# File ~/.local/lib/python3.11/site-packages/dill/_dill.py:420, in Pickler.dump(self, obj)
#     419 logger.trace_setup(self)
# --> 420 StockPickler.dump(self, obj)
#
# File /usr/lib/python3.11/pickle.py:487, in _Pickler.dump(self, obj)
#     486     self.framer.start_framing()
# --> 487 self.save(obj)
#     488 self.write(STOP)
#
# File ~/.local/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~/.local/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#
# File /usr/lib/python3.11/pickle.py:932, in _Pickler.save_list(self, obj)
#     931 self.memoize(obj)
# --> 932 self._batch_appends(obj)
#
# File /usr/lib/python3.11/pickle.py:956, in _Pickler._batch_appends(self, items)
#     955 for x in tmp:
# --> 956     save(x)
#     957 write(APPENDS)
#
# File ~/.local/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~/.local/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /usr/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#
# File ~/.local/lib/python3.11/site-packages/datasets/utils/_dill.py:171, in _save_torchTensor(pickler, obj)
#     169     return tensor
# --> 171 log(pickler, f"To: {obj}")
#     172 if obj.dtype == torch.bfloat16:
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor.py:991, in Tensor.__format__(self, format_spec)
#     990     return self.item().__format__(format_spec)
# --> 991 return object.__format__(self, format_spec)
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor.py:464, in Tensor.__repr__(self, tensor_contents)
#     463 # All strings are unicode in Python 3.
# --> 464 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:697, in _str(self, tensor_contents)
#     696 guard = torch._C._DisableFuncTorch()
# --> 697 return _str_intern(self, tensor_contents=tensor_contents)
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:617, in _str_intern(inp, tensor_contents)
#     616                 else:
# --> 617                     tensor_str = _tensor_str(self, indent)
#     619 if self.layout != torch.strided:
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:350, in _tensor_str(self, indent)
#     349 formatter = _Formatter(get_summarized_data(self) if summarize else self)
# --> 350 return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:272, in _tensor_str_with_formatter(self, indent, summarize, formatter1, formatter2)
#     271 if dim == 1:
# --> 272     return _vector_str(self, indent, summarize, formatter1, formatter2)
#     274 if summarize and self.size(0) > 2 * PRINT_OPTS.edgeitems:
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:253, in _vector_str(self, indent, summarize, formatter1, formatter2)
#     252 else:
# --> 253     data = [_val_formatter(val) for val in self.tolist()]
#     255 data_lines = [
#     256     data[i : i + elements_per_line] for i in range(0, len(data), elements_per_line)
#     257 ]
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:253, in <listcomp>(.0)
#     252 else:
# --> 253     data = [_val_formatter(val) for val in self.tolist()]
#     255 data_lines = [
#     256     data[i : i + elements_per_line] for i in range(0, len(data), elements_per_line)
#     257 ]
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:241, in _vector_str.<locals>._val_formatter(val, formatter1, formatter2)
#     240 else:
# --> 241     return formatter1.format(val)
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:195, in _Formatter.format(self, value)
#     194 if self.sci_mode:
# --> 195     ret = f"{{:{self.max_width}.{PRINT_OPTS.precision}e}}".format(value)
#     196 elif self.int_mode:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 ds["train"].add_column("clip_embeddings",  [embed[0] for embed in embeddings])
#       3 # Now the dataset has a new column 'new_column'
#       4 print(ds)
#
# File ~/.local/lib/python3.11/site-packages/datasets/arrow_dataset.py:567, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     560 self_format = {
#     561     "type": self._format_type,
#     562     "format_kwargs": self._format_kwargs,
#     563     "columns": self._format_columns,
#     564     "output_all_columns": self._output_all_columns,
#     565 }
#     566 # apply actual function
# --> 567 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     568 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     569 # re-apply format to the output
#
# File ~/.local/lib/python3.11/site-packages/datasets/fingerprint.py:474, in fingerprint_transform.<locals>._fingerprint.<locals>.wrapper(*args, **kwargs)
#     472 if kwargs.get(fingerprint_name) is None:
#     473     kwargs_for_fingerprint["fingerprint_name"] = fingerprint_name
# --> 474     kwargs[fingerprint_name] = update_fingerprint(
#     475         dataset._fingerprint, transform, kwargs_for_fingerprint
#     476     )
#     477 else:
#     478     validate_fingerprint(kwargs[fingerprint_name])
#
# File ~/.local/lib/python3.11/site-packages/datasets/fingerprint.py:299, in update_fingerprint(fingerprint, transform, transform_args)
#     296 if _CACHING_ENABLED:
#     297     if not fingerprint_warnings.get("update_fingerprint_transform_hash_failed", False):
#     298         logger.warning(
# --> 299             f"Parameter '{key}'={transform_args[key]} of the transform {transform} couldn't be hashed properly, a random hash was used instead. "
#     300             "Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. "
#     301             "If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. "
#     302             "This warning is only showed once. Subsequent hashing failures won't be showed."
#     303         )
#     304         fingerprint_warnings["update_fingerprint_transform_hash_failed"] = True
#     305     else:
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor.py:464, in Tensor.__repr__(self, tensor_contents)
#     460     return handle_torch_function(
#     461         Tensor.__repr__, (self,), self, tensor_contents=tensor_contents
#     462     )
#     463 # All strings are unicode in Python 3.
# --> 464 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:697, in _str(self, tensor_contents)
#     695 with torch.no_grad(), torch.utils._python_dispatch._disable_current_modes():
#     696     guard = torch._C._DisableFuncTorch()
# --> 697     return _str_intern(self, tensor_contents=tensor_contents)
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:617, in _str_intern(inp, tensor_contents)
#     615                     tensor_str = _tensor_str(self.to_dense(), indent)
#     616                 else:
# --> 617                     tensor_str = _tensor_str(self, indent)
#     619 if self.layout != torch.strided:
#     620     suffixes.append("layout=" + str(self.layout))
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:349, in _tensor_str(self, indent)
#     345     return _tensor_str_with_formatter(
#     346         self, indent, summarize, real_formatter, imag_formatter
#     347     )
#     348 else:
# --> 349     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     350     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor_str.py:179, in _Formatter.__init__(self, tensor)
#     177     self.sci_mode = True
#     178     for value in nonzero_finite_vals:
# --> 179         value_str = f"{{:.{PRINT_OPTS.precision}e}}".format(value)
#     180         self.max_width = max(self.max_width, len(value_str))
#     181 else:
#
# File ~/.local/lib/python3.11/site-packages/torch/_tensor.py:987, in Tensor.__format__(self, format_spec)
#     986 def __format__(self, format_spec):
# --> 987     if has_torch_function_unary(self):
#     988         return handle_torch_function(Tensor.__format__, (self,), self, format_spec)
#     989     if self.dim() == 0 and not self.is_meta and type(self) is Tensor:
#
# KeyboardInterrupt:

# %% [markdown]
# # Save embeddings locally

# %% [markdown]
# # Build the vector database

# %%
# !pip install chromadb

# %%
import chromadb
chroma_client = chromadb.Client()

# %% [markdown]
# # Create ChromaDB

# %%
collection = chroma_client.get_or_create_collection(name="FLAIR_CLIP")

from math import ceil

batch_size = 1000
num_batches = ceil(len(embeddings) / batch_size)

# Loop through each batch
for batch_idx in range(num_batches):
    start_idx = batch_idx * batch_size
    end_idx = min((batch_idx + 1) * batch_size, len(embeddings))

    # Create a batch of embeddings, documents, and ids
    batch_embeddings = [e[0].tolist() for e in embeddings[start_idx:end_idx]]
    batch_documents = list(range(start_idx, end_idx))
    batch_ids = [f"image_{i}" for i in range(start_idx, end_idx)]

    # Add the batch to the collection
    collection.add(
        embeddings=batch_embeddings,
        documents=batch_documents,
        metadatas=None,  # Assuming you still don't need metadata
        ids=batch_ids
    )

# %%
search_string = "treehouse"

query_embedding = clip_embed(images=None, text=search_string)[0].tolist()

results = collection.query(
    query_embeddings=[query_embedding],
    n_results=5
)
print(results)
# Out:
# {'ids': [['image_4442', 'image_4673', 'image_4525', 'image_4131', 'image_4134']], 'distances': [[147.169677734375, 147.169677734375, 147.169677734375, 147.169677734375, 147.169677734375]], 'metadatas': [[None, None, None, None, None]], 'embeddings': None, 'documents': [['4442', '4673', '4525', '4131', '4134']], 'uris': None, 'data': None, 'included': ['metadatas', 'documents', 'distances']}
